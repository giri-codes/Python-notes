# %%
# PYTHON VARIABLES — Giri's Practice Notebook
# Topic: Variables + Variable Naming Rules


# COMMENTS:
# To explain Python code we use comments that symbols "#":

# Now you are reading this,This is also a comment:

# VARIABLES:
# Variables are containers for storing data values:

# Creating Variables:

a = 8
b = "Giri"
print(a)
print(b)
# Out:
# 8
# Giri

# %%
# Example 1: store basic information

name = "Giri"      # person's name
age = 22           # person's age
city = "Mysore"    # current city

print(name, age, city)
# Out:
# Giri 22 Mysore

# %%
a = 8431      # is int
a = "Giri"   # is now str
print(a)
# Out:
# Giri

# %%
# Casting:
a = str(4)   # a will be '4'
b = int(4)   # b will be 4
c = float(4) # c will be 4.0

print(a)
print(b)
print(c)
# Out:
# 4
# 4
# 4.0

# %%
#To get Type:
a = 8
b = "Giri"
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# We can use Both single or Double quotes:

g = "Gireesh"
print(g)
#  same as
g = 'Gireesh'
print(g)
# Out:
# Gireesh
# Gireesh

# %%
# Variable names = Case-sensitive:

g = 8
G = "Gireesh"      # Both g and G are different not same:

print(g)
print(G)
# Out:
# 8
# Gireesh

# %%
# Variable Naming Rules (Giri's Notes)

# 1. Must start with a letter (a–z / A–Z) or underscore (_)
# 2. Cannot start with a number
# 3. Can contain letters, numbers, and underscores
# 4. Case-sensitive (age ≠ Age)
# 5. No special characters like @, #, $, %, etc.
# 6. Python keywords are not variable names.

# Legal_Variable_names:
myname = "Giri"
his_name = "Ganesh"
_her_name = "Geeta"
myFriendName = "Akash"
MYBRONAME = "Gagan"
mysis2 = "Rekha"

print(myname)
print(his_name)
print(_her_name)
print(myFriendName)
print(MYBRONAME)
print(mysis2)
# Out:
# Giri
# Ganesh
# Geeta
# Akash
# Gagan
# Rekha

# %%
# Illegal Variable Names (these cause errors)
# 1myname = "Giri"
# his-name = "Gagan"
# her name = "Geeta"

# %%
# Three techniques to read variable_names:

# 1 Camel Case: Except the first one each word start with a capital letter:
myName = "Giri"
print(myName)

# 2 Pascal Case: Each word starts with a capital letter:
MyGoal = "Developer"
print(MyGoal)

# 3 Snake_Case: It is seperated by an underscore character:
my_monthly_salary = 100000
print(my_monthly_salary)
# Out:
# Giri
# Developer
# 100000
